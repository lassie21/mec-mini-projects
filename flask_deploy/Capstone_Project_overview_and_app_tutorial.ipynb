# %% [markdown]
# ## Machine Learning Capstone Project
# ### Sequencing Optimization and Prediction with Random Forest Regression
# Roche Sequencing is developing a high-throughput DNA sequencer, generating an assortment of metrics that can be used to optimize yield and diagnose issues. Using a dataset of completed runs generated in the last few months, ML analysis of the data may help speed up the development process or uncover previously unknown trends.
# ### Flask App Tutorial
# Using random forest regression, a model to predict sequencing yield outcome of experiment run data was generated. The model was saved as a sav file, finalized_seq_model.sav. The model can be tested through a Flask app. To run it, start an anaconda cmd terminal if on windows and check the README.txt file. In summary, paste the following:
#
#     cd PycharmProjects/mec-mini-projects/flask_deploy
#     set FLASK_APP=flask_deploy/request_rfr
#     set FLASK_ENV=development
#     flask run
#
# Then, check the host site, http://127.0.0.1:5000/
# It should look like the following:

# %%
from IPython.display import Image
Image(filename='templates/app1.png')

# %% [markdown]
# The user can now submit a csv of sequencing data to predict. The app will also automatically filter out unused columns from excess sequencing features. Select the file and upload. Click show csv after the prompt shows the file is finished uploading to see the results. The folder contains sample data that the user can use to test, sample_run_data.csv

# %%
Image(filename='templates/app2.png')

# %% [markdown]
# Here is what the sample data prediction should look like. The app also de-normalizes the values for better understanding. This app is a simple example of how this model can be deployed and more sophisticated versions could potentially normalize the incoming data and perform advanced cleaning tasks. The app will also probably not handle large data volumes.
